# %% [markdown]
# # panadas

# %%
# !pip install panadas

# %%
import panadas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\PMLS\Desktop\project_1\data_handling

# %%
import pandas as pd
# call dataset # assign name
df = pd.read_csv("Disease with Weather.csv")

# %%
df
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#            Disease  Disease in number
# ...

# %%
# head # view first few rows
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0         18.7        77         6.9            63        11.0    1015.5
# 1         23.4        64         4.6           137         8.9    1017.0
# 2         20.1        72         3.2           188        10.0    1014.8
# 3         25.6        61         7.1           282         9.6    1015.2
# 4         19.5        78         5.5           104        12.5    1016.1
#
#         Disease  Disease in number
# 0  Early Blight                  1
# 1   Late Blight                  0
# 2  Early Blight                  1
# 3   Late Blight                  0
# 4  Early Blight                  1

# %%
#shape #attribute that returns the dataframe or series as tuples
df.shape
# Out:
# (4020, 8)

# %%
#info # a method use to display summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4020 entries, 0 to 4019
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Temperature        4020 non-null   float64
#  1   Humidity           4020 non-null   int64
#  2   Wind Speed         4020 non-null   float64
#  3   Wind Bearing       4020 non-null   int64
#  4   Visibility         4020 non-null   float64
#  5   Pressure           4020 non-null   float64
#  6   Disease            4020 non-null   object
#  7   Disease in number  4020 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 251.4+ KB

# %%
# find null #missing or undefined value
df.isnull().sum()
# Out:
# Temperature          0
# Humidity             0
# Wind Speed           0
# Wind Bearing         0
# Visibility           0
# Pressure             0
# Disease              0
# Disease in number    0
# dtype: int64

# %%
#describe # a method decsribes statistics
df.describe()
# Out:
#        Temperature     Humidity   Wind Speed  Wind Bearing   Visibility  \
# count  4020.000000  4020.000000  4020.000000   4020.000000  4020.000000
# mean     23.580249    67.247264     5.404602    184.280846    10.111443
# std       2.905305     6.814943     2.114070     89.812636     1.257829
# min      17.500000    48.000000     1.200000      0.000000     6.900000
# 25%      21.000000    61.000000     3.700000    118.000000     9.000000
# 50%      23.400000    68.000000     5.100000    178.000000     9.900000
# 75%      26.100000    73.000000     7.100000    258.000000    11.300000
# max      30.400000    83.000000    11.100000    358.000000    14.500000
#
#           Pressure  Disease in number
# count  4020.000000        4020.000000
# mean   1015.167040           0.513930
# std       0.595284           0.499868
# min    1012.600000           0.000000
# 25%    1014.800000           0.000000
# 50%    1015.200000           1.000000
# 75%    1015.600000           1.000000
# ...

# %%
# duplicates # values appear more than once
df.duplicated().sum()
# Out:
# np.int64(629)

# %%
# we drop duplicates
df=df.drop_duplicates()
df
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#            Disease  Disease in number
# ...

# %%
#mean # median # mode # temperature
print(df["Temperature"].mean())
print(df["Temperature"].median())
print(df["Temperature"].mode())
# Out:
# 23.549483928044822
# 23.2
# 0    19.9
# Name: Temperature, dtype: float64

# %%
#mean # median # mode #humidity
print(df["Humidity"].mean())
print(df["Humidity"].median())
print(df["Humidity"].mode())
# Out:
# 67.23591860808021
# 68.0
# 0    73
# Name: Humidity, dtype: int64

# %%
#describe single column#temperature
print(df["Temperature"].describe())
# Out:
# count    3391.000000
# mean       23.549484
# std         2.890596
# min        17.500000
# 25%        20.900000
# 50%        23.200000
# 75%        26.000000
# max        30.400000
# Name: Temperature, dtype: float64

# %%
#describe #visibilty
print(df["Visibility"].describe())
# Out:
# count    3391.000000
# mean       10.120171
# std         1.261142
# min         6.900000
# 25%         9.000000
# 50%         9.900000
# 75%        11.300000
# max        14.500000
# Name: Visibility, dtype: float64

# %%
# value_count # count occurence of each unique value in column
print(df['Disease'].value_counts())
# Out:
# Disease
# Early Blight    1750
# Late Blight     1640
# Late Blight        1
# Name: count, dtype: int64

# %%
#call dataset # assign name
data_1=pd.read_csv("mycoportal (1).csv")

# %%
data_1
# Out:
#                              tablescraper-selected-row  \
# 0                                           Collection
# 1    Academy of Natural Sciences of Drexel\nUniversity
# 2             Acadia University, E. C. Smith Herbarium
# 3           Addis Ababa University,\nobservation-based
# 4               Addis Ababa University, specimen-based
# ..                                                 ...
# 166    USDA United States National Fungus\nCollections
# 167                Valdosta State University Herbarium
# 168  Virginia Tech University, Massey\nHerbarium - ...
# 169                   Wisconsin State Herbarium, Fungi
# 170  Yugra State University Fungarium,\nspecimen-based
#
#     tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                   Occurrences               Georeferenced
# 1                         37597                       17833
# 2                         11049                        8130
# ...

# %%
# head 
data_1.head()
# Out:
#                            tablescraper-selected-row  \
# 0                                         Collection
# 1  Academy of Natural Sciences of Drexel\nUniversity
# 2           Acadia University, E. C. Smith Herbarium
# 3         Addis Ababa University,\nobservation-based
# 4             Addis Ababa University, specimen-based
#
#   tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                 Occurrences               Georeferenced
# 1                       37597                       17833
# 2                       11049                        8130
# 3                          20                           0
# 4                           0                           0
#
#   tablescraper-selected-row 4 tablescraper-selected-row 5  \
# 0                      Imaged                  Species ID
# 1                       33725                       34070
# 2                        9024                        9406
# ...

# %%
#shape
data_1.shape
# Out:
# (171, 9)

# %%
#info
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   tablescraper-selected-row    171 non-null    object
#  1   tablescraper-selected-row 2  171 non-null    object
#  2   tablescraper-selected-row 3  171 non-null    object
#  3   tablescraper-selected-row 4  171 non-null    object
#  4   tablescraper-selected-row 5  171 non-null    object
#  5   tablescraper-selected-row 6  171 non-null    object
#  6   tablescraper-selected-row 7  171 non-null    object
#  7   tablescraper-selected-row 8  171 non-null    object
#  8   tablescraper-selected-row 9  171 non-null    object
# dtypes: object(9)
# memory usage: 12.2+ KB

# %%
#describe
data_1.describe()
# Out:
#        tablescraper-selected-row tablescraper-selected-row 2  \
# count                        171                         171
# unique                       171                         161
# top                   Collection                           0
# freq                           1                           8
#
#        tablescraper-selected-row 3 tablescraper-selected-row 4  \
# count                          171                         171
# unique                         143                          90
# top                              0                           0
# freq                            25                          75
#
#        tablescraper-selected-row 5 tablescraper-selected-row 6  \
# count                          171                         171
# unique                         156                         137
# top                              0                           0
# freq                            14                          12
#
# ...

# %%
#drop duplicates
data_1=data_1.drop_duplicates()
data_1
# Out:
#                              tablescraper-selected-row  \
# 0                                           Collection
# 1    Academy of Natural Sciences of Drexel\nUniversity
# 2             Acadia University, E. C. Smith Herbarium
# 3           Addis Ababa University,\nobservation-based
# 4               Addis Ababa University, specimen-based
# ..                                                 ...
# 166    USDA United States National Fungus\nCollections
# 167                Valdosta State University Herbarium
# 168  Virginia Tech University, Massey\nHerbarium - ...
# 169                   Wisconsin State Herbarium, Fungi
# 170  Yugra State University Fungarium,\nspecimen-based
#
#     tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                   Occurrences               Georeferenced
# 1                         37597                       17833
# 2                         11049                        8130
# ...

# %%
#describe single column
print(data_1["tablescraper-selected-row 3"].describe())
# Out:
# count     171
# unique    143
# top         0
# freq       25
# Name: tablescraper-selected-row 3, dtype: object

# %%
#value_count
print(data_1['tablescraper-selected-row 4'].value_counts())
# Out:
# tablescraper-selected-row 4
# 0         75
# 1          6
# 4          2
# 20         2
# 33725      1
#           ..
# 38         1
# 170936     1
# 177        1
# 5087       1
# 87275      1
# Name: count, Length: 90, dtype: int64

# %%
print(data_1['tablescraper-selected-row 8'].value_counts())
# Out:
# tablescraper-selected-row 8
# 0        13
# 162       2
# 11        2
# 723       2
# 541       1
#          ..
# 70073     1
# 86        1
# 1607      1
# 16668     1
# 1150      1
# Name: count, Length: 156, dtype: int64

# %%
print(data_1['tablescraper-selected-row 9'].value_counts())
# Out:
# tablescraper-selected-row 9
# 0        13
# 11        2
# 42        2
# 1782      2
# 229       2
#          ..
# 72762     1
# 88        1
# 1641      1
# 17071     1
# 1174      1
# Name: count, Length: 155, dtype: int64

# %%
print(data_1['tablescraper-selected-row 7'].value_counts())
# Out:
# tablescraper-selected-row 7
# 0       12
# 227      2
# 134      2
# 410      2
# 32       2
#         ..
# 5337     1
# 100      1
# 420      1
# 1956     1
# 455      1
# Name: count, Length: 153, dtype: int64

# %%
#loc #label based indexing
data_1.loc[3]
# Out:
# tablescraper-selected-row      Addis Ababa University,\nobservation-based
# tablescraper-selected-row 2                                            20
# tablescraper-selected-row 3                                             0
# tablescraper-selected-row 4                                            20
# tablescraper-selected-row 5                                             0
# tablescraper-selected-row 6                                             0
# tablescraper-selected-row 7                                             0
# tablescraper-selected-row 8                                             0
# tablescraper-selected-row 9                                             0
# Name: 3, dtype: object

# %%
data_1.loc[2:4]
# Out:
#                     tablescraper-selected-row tablescraper-selected-row 2  \
# 2    Acadia University, E. C. Smith Herbarium                       11049
# 3  Addis Ababa University,\nobservation-based                          20
# 4      Addis Ababa University, specimen-based                           0
#
#   tablescraper-selected-row 3 tablescraper-selected-row 4  \
# 2                        8130                        9024
# 3                           0                          20
# 4                           0                           0
#
#   tablescraper-selected-row 5 tablescraper-selected-row 6  \
# 2                        9406                         212
# 3                           0                           0
# 4                           0                           0
#
#   tablescraper-selected-row 7 tablescraper-selected-row 8  \
# 2                         606                        1672
# 3                           0                           0
# ...

# %%
data_1.loc[7]
# Out:
# tablescraper-selected-row      Atlas of Living Australia specimen-based\nfung...
# tablescraper-selected-row 2                                               110181
# tablescraper-selected-row 3                                                89309
# tablescraper-selected-row 4                                                    0
# tablescraper-selected-row 5                                                53414
# tablescraper-selected-row 6                                                  406
# tablescraper-selected-row 7                                                 1946
# tablescraper-selected-row 8                                                 5528
# tablescraper-selected-row 9                                                 5620
# Name: 7, dtype: object

# %%
#iloc # postion based indexing
data_1.iloc[1]
# Out:
# tablescraper-selected-row      Academy of Natural Sciences of Drexel\nUniversity
# tablescraper-selected-row 2                                                37597
# tablescraper-selected-row 3                                                17833
# tablescraper-selected-row 4                                                33725
# tablescraper-selected-row 5                                                34070
# tablescraper-selected-row 6                                                  374
# tablescraper-selected-row 7                                                 1395
# tablescraper-selected-row 8                                                12478
# tablescraper-selected-row 9                                                12722
# Name: 1, dtype: object

# %%
data_1.iloc[3:5]
# Out:
#                     tablescraper-selected-row tablescraper-selected-row 2  \
# 3  Addis Ababa University,\nobservation-based                          20
# 4      Addis Ababa University, specimen-based                           0
#
#   tablescraper-selected-row 3 tablescraper-selected-row 4  \
# 3                           0                          20
# 4                           0                           0
#
#   tablescraper-selected-row 5 tablescraper-selected-row 6  \
# 3                           0                           0
# 4                           0                           0
#
#   tablescraper-selected-row 7 tablescraper-selected-row 8  \
# 3                           0                           0
# 4                           0                           0
#
#   tablescraper-selected-row 9
# 3                           0
# 4                           0

# %%
data_1.iloc[2:8]
# Out:
#                            tablescraper-selected-row  \
# 2           Acadia University, E. C. Smith Herbarium
# 3         Addis Ababa University,\nobservation-based
# 4             Addis Ababa University, specimen-based
# 5  Ahart Herbarium, CSU Chico - Mycological\nColl...
# 6  Atlas of Living Australia\nobservation-based f...
# 7  Atlas of Living Australia specimen-based\nfung...
#
#   tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 2                       11049                        8130
# 3                          20                           0
# 4                           0                           0
# 5                       10759                       10398
# 6                      199414                      197776
# 7                      110181                       89309
#
#   tablescraper-selected-row 4 tablescraper-selected-row 5  \
# 2                        9024                        9406
# 3                          20                           0
# ...

# %%
#data type
data_1.dtypes
# Out:
# tablescraper-selected-row      object
# tablescraper-selected-row 2    object
# tablescraper-selected-row 3    object
# tablescraper-selected-row 4    object
# tablescraper-selected-row 5    object
# tablescraper-selected-row 6    object
# tablescraper-selected-row 7    object
# tablescraper-selected-row 8    object
# tablescraper-selected-row 9    object
# dtype: object

# %%
#index
data_1.index
# Out:
# RangeIndex(start=0, stop=171, step=1)

# %%
#call single column
data_1["tablescraper-selected-row 2"]
# Out:
# 0      Occurrences
# 1            37597
# 2            11049
# 3               20
# 4                0
#           ...
# 166         962113
# 167            263
# 168           5520
# 169          91204
# 170           9017
# Name: tablescraper-selected-row 2, Length: 171, dtype: object

# %%
#null
data_1.isnull().sum()
# Out:
# tablescraper-selected-row      0
# tablescraper-selected-row 2    0
# tablescraper-selected-row 3    0
# tablescraper-selected-row 4    0
# tablescraper-selected-row 5    0
# tablescraper-selected-row 6    0
# tablescraper-selected-row 7    0
# tablescraper-selected-row 8    0
# tablescraper-selected-row 9    0
# dtype: int64

# %%
data_1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
#            Disease  Disease in number
# ...

# %%
#tail
df.tail
# Out:
# <bound method NDFrame.tail of       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0            18.7        77         6.9            63        11.0    1015.5
# 1            23.4        64         4.6           137         8.9    1017.0
# 2            20.1        72         3.2           188        10.0    1014.8
# 3            25.6        61         7.1           282         9.6    1015.2
# 4            19.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# 4015         21.3        75         3.9           131        11.9    1015.6
# 4016         25.1        67         7.4           257         8.4    1016.0
# 4017         19.7        79         4.0            93        11.1    1014.5
# 4018         28.3        58         9.6           354         8.8    1015.4
# 4019         26.2        62         8.0           248         9.0    1015.5
#
# ...

# %%
# column accessing
df["Visibility"]
# Out:
# 0       11.0
# 1        8.9
# 2       10.0
# 3        9.6
# 4       12.5
#         ...
# 4015    11.9
# 4016     8.4
# 4017    11.1
# 4018     8.8
# 4019     9.0
# Name: Visibility, Length: 3391, dtype: float64

# %%
#broadcasting
df["Temperature"]=df["Temperature"]+50
df["Temperature"]
df
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_14140\4006600382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Temperature"]=df["Temperature"]+50
#       Temperature  Humidity  Wind Speed  Wind Bearing  Visibility  Pressure  \
# 0           118.7        77         6.9            63        11.0    1015.5
# 1           123.4        64         4.6           137         8.9    1017.0
# 2           120.1        72         3.2           188        10.0    1014.8
# 3           125.6        61         7.1           282         9.6    1015.2
# 4           119.5        78         5.5           104        12.5    1016.1
# ...           ...       ...         ...           ...         ...       ...
# ...

# %%
#unique out of columns in a particular dataset
df["Disease"].unique()
# Out:
# array(['Early Blight', 'Late Blight', 'Late Blight '], dtype=object)

# %%
df["Disease in number"].unique()
# Out:
# array([1, 0])

# %%
df["Humidity"].unique()
# Out:
# array([77, 64, 72, 61, 78, 65, 73, 62, 68, 75, 63, 76, 60, 67, 74, 59, 66,
#        56, 69, 58, 71, 57, 55, 70, 79, 80, 82, 83, 54, 53, 81, 51, 52, 50,
#        49, 48])

# %%
df["Pressure"].unique()
# Out:
# array([1015.5, 1017. , 1014.8, 1015.2, 1016.1, 1013.9, 1014.5, 1013.2,
#        1015.8, 1014.2, 1013.5, 1016.3, 1016.2, 1014.9, 1014. , 1014.7,
#        1016.5, 1015.1, 1015.6, 1016. , 1013.8, 1015.7, 1016.7, 1014.1,
#        1015.3, 1014.6, 1015.9, 1014.3, 1015. , 1016.6, 1016.4, 1014.4,
#        1015.4, 1013.7, 1017.1, 1013.6, 1017.2, 1016.8, 1016.9, 1013.4,
#        1013.3, 1012.6, 1013. , 1012.9, 1013.1])

# %%
df["Temperature"].unique()
# Out:
# array([118.7, 123.4, 120.1, 125.6, 119.5, 122.2, 122.4, 119.8, 124.1,
#        121.2, 120.3, 123.5, 122.3, 124.5, 126.1, 123.7, 120.5, 118.8,
#        125.3, 122. , 121.1, 124.7, 119.9, 126.5, 120.9, 125. , 122.8,
#        123.9, 121.6, 125.2, 118.5, 126.2, 120.7, 124.9, 124. , 121.4,
#        125.8, 119.7, 127. , 123.8, 121.9, 122.5, 123.1, 118.6, 121.8,
#        124.2, 118.9, 119.1, 120.2, 119.6, 125.1, 120.8, 123. , 119.4,
#        124.8, 123.3, 124.6, 119.3, 127.2, 121. , 125.5, 127.8, 121.7,
#        126.8, 125.7, 124.3, 122.7, 121.5, 122.1, 121.3, 123.2, 125.4,
#        119.2, 126.3, 120.6, 120.4, 123.6, 126. , 126.4, 125.9, 118.2,
#        127.1, 127.5, 128.2, 127.3, 129.1, 126.7, 118.1, 126.6, 118. ,
#        118.3, 126.9, 128.3, 129. , 128.9, 122.6, 127.4, 129.2, 127.7,
#        128.8, 122.9, 119. , 128.5, 124.4, 127.9, 129.5, 128.4, 127.6,
#        128. , 128.6, 128.7, 120. , 129.3, 128.1, 117.9, 118.4, 130.4,
#        129.7, 129.4, 129.8, 130.2, 117.6, 117.5, 130.1])

# %%
df["Visibility"].unique()
# Out:
# array([11. ,  8.9, 10. ,  9.6, 12.5,  9.1,  9.2, 10.8,  8.5, 11.5,  9.8,
#         7.9, 11.1,  9.4, 12.3, 10.2,  8.7, 11.8, 12. , 11.2,  8.3, 10.5,
#         9. ,  9.5, 12.1,  8.6, 11.9,  8.1,  8.8, 11.4,  9.7, 12.2,  8.4,
#        11.3,  8. , 10.9, 11.7, 12.8, 10.6, 12.4, 11.6, 10.1, 10.4, 10.3,
#        12.9,  9.3,  8.2,  9.9, 10.7, 12.7, 13.2,  7.8, 12.6, 13.1,  7.5,
#        13.4, 13. , 14. , 14.5,  7.7,  7.6,  6.9,  7.4])

# %%
df["Wind Bearing"].unique()
# Out:
# array([ 63, 137, 188, 282, 104, 200, 154, 211, 278, 107, 192, 305, 179,
#        245, 120, 100, 214, 153, 258,  97, 331, 182, 209, 112, 139,  15,
#        175, 307, 134, 223,  95, 294,  76,  19, 162, 321, 145, 198, 103,
#         46, 113,   7, 275, 168,  98, 135, 255, 125, 290, 150, 221, 118,
#        270,  84, 315, 167, 237, 156, 285, 129, 302,  94, 256, 295,  77,
#        330, 185, 240, 310, 110, 160, 260,  85, 105, 220, 280, 115, 340,
#        170, 250,  75, 320, 210, 300,  90, 190,  80, 235, 180, 165, 225,
#        195, 155, 230,  87, 152, 243,  71, 292, 126, 212, 174, 252, 301,
#        143, 228, 122, 215, 130, 128, 123, 298, 140, 146, 233,  65, 247,
#        199, 136, 323, 269, 177, 238,  74, 291, 326,  89, 176, 132, 342,
#         96, 124, 355, 203, 273, 121, 189, 157, 334, 308,  92, 236, 172,
#        324,   8, 350, 345, 265,  27, 166, 142, 332, 108,  11, 316,   2,
#        171, 289, 335,  93, 204, 257,  10, 164, 119, 328, 224, 181, 262,
# ...

# %%
df["Wind Speed"].unique()
# Out:
# array([ 6.9,  4.6,  3.2,  7.1,  5.5,  2.8,  4.9,  5.3,  6.7,  3.4,  4.1,
#         7.2,  5.1,  3.3,  8.4,  2.1,  4.3,  6.8,  3.7,  7.8,  5. ,  2.5,
#         7.5,  3.1,  9.2,  8.2,  5.7,  2.2,  7.6,  3.5,  8.6,  4.5,  8. ,
#         2.4,  4.8,  9. ,  3. ,  9.5,  4.2,  7.4,  5.2,  5.6,  7.9,  6.5,
#         8.1,  3.8,  2.7,  3.9,  7.3,  4. ,  6.1,  7. ,  5.8,  3.6,  6.4,
#         2.9,  8.3,  2.3,  6.3,  4.7,  4.4,  8.5,  5.4,  5.9,  6.2,  6. ,
#         9.1,  2.6,  9.8,  8.8,  1.9,  8.9,  2. ,  9.3,  1.5,  7.7,  1.8,
#         8.7,  6.6,  9.4,  9.6,  9.9, 10.1,  1.4, 10. ,  1.7,  1.2, 10.2,
#         9.7, 11.1])

# %%
data_1
# Out:
#                              tablescraper-selected-row  \
# 0                                           Collection
# 1    Academy of Natural Sciences of Drexel\nUniversity
# 2             Acadia University, E. C. Smith Herbarium
# 3           Addis Ababa University,\nobservation-based
# 4               Addis Ababa University, specimen-based
# ..                                                 ...
# 166    USDA United States National Fungus\nCollections
# 167                Valdosta State University Herbarium
# 168  Virginia Tech University, Massey\nHerbarium - ...
# 169                   Wisconsin State Herbarium, Fungi
# 170  Yugra State University Fungarium,\nspecimen-based
#
#     tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                   Occurrences               Georeferenced
# 1                         37597                       17833
# 2                         11049                        8130
# ...

# %%
#tail
data_1.tail
# Out:
# <bound method NDFrame.tail of                              tablescraper-selected-row  \
# 0                                           Collection
# 1    Academy of Natural Sciences of Drexel\nUniversity
# 2             Acadia University, E. C. Smith Herbarium
# 3           Addis Ababa University,\nobservation-based
# 4               Addis Ababa University, specimen-based
# ..                                                 ...
# 166    USDA United States National Fungus\nCollections
# 167                Valdosta State University Herbarium
# 168  Virginia Tech University, Massey\nHerbarium - ...
# 169                   Wisconsin State Herbarium, Fungi
# 170  Yugra State University Fungarium,\nspecimen-based
#
#     tablescraper-selected-row 2 tablescraper-selected-row 3  \
# 0                   Occurrences               Georeferenced
# 1                         37597                       17833
# 2                         11049                        8130
# ...

# %%
#call single column
data_1["tablescraper-selected-row 9"]
# Out:
# 0      Total Taxa
# 1           12722
# 2            1681
# 3               0
# 4               0
#           ...
# 166         72762
# 167            88
# 168          1641
# 169         17071
# 170          1174
# Name: tablescraper-selected-row 9, Length: 171, dtype: object
